# %% [markdown]
# <a href="https://colab.research.google.com/github/shamiya829/AI-Society-and-Humanity/blob/main/web_app_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install happytransformer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# New
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# New
from datasets import load_dataset

# %% [markdown]
# https://github.com/EricFillion/happy-transformer

# %%
from happytransformer import HappyGeneration, GENSettings

# %% [markdown]
# https://happytransformer.com/text-generation/settings/

# %% [markdown]
# ### Create a HappyGeneration object

# %%
happy_gen = HappyGeneration('GPT-NEO', "EleutherAI/gpt-neo-1.3B")
# happy_gen = HappyGeneration('GPT-NEO', "EleutherAI/gpt-neo-125M")

# %% [markdown]
# ## Training Data

# %%
train_path = "train.txt"

# %%
train_dataset = load_dataset("billsum", split="train[0:3000]")
# Out:
# ...
# Generating ca_test split:   0%|          | 0/1237 [00:00<?, ? examples/s]
# Dataset billsum downloaded and prepared to /root/.cache/huggingface/datasets/billsum/default/3.0.0/75cf1719d38d6553aa0e0714c393c74579b083ae6e164b2543684e3e92e0c4cc. Subsequent calls will reuse this data.

# %%
def generate_text(path, dataset):
  with open(path, "w") as text_file:
    for case in dataset:
      text = case["summary"]
      text_file.write(text + "\n")

# %%
generate_text(train_path, train_dataset)

# %% [markdown]
# ### Train

# %%
happy_gen.train(train_path)
# Out:
# WARNING:datasets.builder:Using custom data configuration default-27ee59e96f5365ec
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-27ee59e96f5365ec/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
# ...
#   0%|          | 0/12 [00:00<?, ?ba/s]
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 332
#   Num Epochs = 3
# ...

# %% [markdown]
# ## Generation Settings

# %%
max_length = 100

# %%
top_k_sampling_settings = GENSettings(do_sample=True, early_stopping=False, top_k=10, temperature=0.5, no_repeat_ngram_size=3,  max_length=max_length)

# %%
generic_sampling_settings = GENSettings(do_sample=True, early_stopping=False, top_k=0, temperature=0.7, no_repeat_ngram_size=3,  max_length=max_length)

# %%
greedy_settings = GENSettings(no_repeat_ngram_size=2,  max_length=max_length)

# %%
algos = {"top-k sampling": top_k_sampling_settings,
         "generic sampling": generic_sampling_settings,
         'greedy': greedy_settings,
}

# %% [markdown]
# ### Install anvil-uplink

# %%
pip install anvil-uplink

# %% [markdown]
# ### import anvil.server

# %%
import anvil.server

# %% [markdown]
# ### Connect to Anvil

# %% [markdown]
# Top of Colab

# %%
anvil.server.connect("VBH2CLISS2WHAGISDLQW3OQN-QC7CWVT3MAWGYNHK")

# %% [markdown]
# ### Create a @anvil.server.callable function

# %%
@anvil.server.callable
def generate_text(text_input, algo_input):
  args = algos[algo_input]
  result = happy_gen.generate_text(text_input, args=args)
  return result.text

# %% [markdown]
# ### Wait Forever

# %%
anvil.server.wait_forever()
